# %%
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_country'] == 'United States') & (df['job_title_short'] == 'Data Analyst')]

# %%
df_DA_US['job_posted_month_no'] = df_DA_US['job_posted_date'].dt.month
# Out:
# C:\Users\14312\AppData\Local\Temp\ipykernel_27984\1948735341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DA_US['job_posted_month_no'] = df_DA_US['job_posted_date'].dt.month

# %%
df_DA_US_explode = df_DA_US.explode('job_skills')

# %%
df_DA_US_pivot = df_DA_US_explode.pivot_table(index ='job_posted_month_no',columns = 'job_skills',aggfunc = 'size',fill_value = 0)
df_DA_US_pivot.loc['Total'] = df_DA_US_pivot.sum()
df_DA_US_pivot = df_DA_US_pivot[df_DA_US_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_US_pivot = df_DA_US_pivot.drop('Total')

# %%
DA_totals = df_DA_US.groupby('job_posted_month_no').size()
DA_totals
# Out:
# job_posted_month_no
# 1     8494
# 2     6124
# 3     6218
# 4     6049
# 5     4993
# 6     5683
# 7     5201
# 8     6634
# 9     4639
# 10    5271
# 11    4531
# 12    3979
# dtype: int64

# %%
df_DA_US_pivot.iloc[:, :10].plot(kind = 'line')
# Out:
# <Axes: xlabel='job_posted_month_no'>

# %%
df_DA_US_percent = df_DA_US_pivot.div(DA_totals/100,axis = 0)

df_DA_US_percent
# Out:
# job_skills                 sql      excel    tableau     python        sas  \
# job_posted_month_no
# 1                    54.167648  42.288674  29.291264  26.536379  21.568166
# 2                    51.730895  42.243632  27.367734  26.420640  19.790986
# 3                    51.881634  42.795111  29.012544  27.066581  19.909939
# 4                    53.231939  42.139197  29.575136  27.756654  21.524219
# 5                    51.692369  42.419387  28.680152  27.017825  19.467254
# 6                    50.360725  41.914482  28.646841  28.312511  17.314799
# 7                    50.163430  40.722938  29.475101  27.648529  19.150163
# 8                    51.462165  41.166717  29.409105  30.524570  19.234248
# 9                    49.471869  38.823022  29.165768  26.492779  18.452253
# 10                   48.833238  36.463669  27.110605  26.048188  18.212863
# 11                   45.332156  33.833591  25.336570  23.151622  17.479585
# 12                   46.443830  38.326213  27.142498  27.041970  19.602915
#
# job_skills                   r   power bi       word  powerpoint    oracle  \
# job_posted_month_no
# 1                    17.812574  15.740523  11.396280   11.443372  8.453026
# 2                    17.064010  18.321359  12.050947   11.512084  8.393207
# 3                    18.349952  16.950788  11.836603   10.759087  6.722419
# 4                    17.159861  17.473963  11.489502   10.745578  7.257398
# 5                    17.364310  17.224114  11.155618   10.314440  7.170038
# 6                    17.895478  17.402780  12.686961   10.980116  7.284885
# 7                    16.939050  16.939050  11.286291   10.555662  7.710056
# 8                    19.158879  18.209225  11.335544   11.245101  7.295749
# 9                    16.081052  17.676223  10.303945   10.239276  7.738737
# 10                   15.841396  17.472965   9.447923    8.973629  8.214760
# 11                   14.279409  15.051865   9.490179    8.894284  6.753476
# 12                   16.536818  17.567228  11.334506    9.901985  6.659965
#
# job_skills           ...  capacitor   chainer  asp.net core        qt  \
# job_posted_month_no  ...
# 1                    ...   0.011773  0.000000      0.000000  0.000000
# 2                    ...   0.000000  0.000000      0.000000  0.000000
# 3                    ...   0.000000  0.000000      0.000000  0.000000
# 4                    ...   0.000000  0.000000      0.000000  0.000000
# 5                    ...   0.000000  0.000000      0.000000  0.000000
# 6                    ...   0.000000  0.000000      0.000000  0.017596
# 7                    ...   0.000000  0.000000      0.000000  0.000000
# 8                    ...   0.000000  0.000000      0.000000  0.000000
# 9                    ...   0.000000  0.000000      0.000000  0.000000
# 10                   ...   0.000000  0.000000      0.018972  0.000000
# 11                   ...   0.000000  0.000000      0.000000  0.000000
# 12                   ...   0.000000  0.025132      0.000000  0.000000
#
# job_skills           microsoft lists  msaccess    kotlin  openstack    theano  \
# job_posted_month_no
# 1                           0.000000  0.000000  0.000000   0.000000  0.000000
# 2                           0.000000  0.000000  0.000000   0.000000  0.000000
# 3                           0.000000  0.000000  0.000000   0.000000  0.000000
# 4                           0.000000  0.000000  0.000000   0.000000  0.000000
# 5                           0.000000  0.020028  0.000000   0.000000  0.000000
# 6                           0.000000  0.000000  0.017596   0.017596  0.000000
# 7                           0.000000  0.000000  0.000000   0.000000  0.000000
# 8                           0.000000  0.000000  0.000000   0.000000  0.000000
# 9                           0.000000  0.000000  0.000000   0.000000  0.000000
# 10                          0.000000  0.000000  0.000000   0.000000  0.000000
# 11                          0.000000  0.000000  0.000000   0.000000  0.000000
# 12                          0.025132  0.000000  0.000000   0.000000  0.025132
#
# job_skills            xamarin
# job_posted_month_no
# 1                    0.000000
# 2                    0.000000
# 3                    0.016082
# 4                    0.000000
# 5                    0.000000
# 6                    0.000000
# 7                    0.000000
# 8                    0.000000
# 9                    0.000000
# 10                   0.000000
# 11                   0.000000
# 12                   0.000000
#
# [12 rows x 218 columns]

# %%
df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month')
df_DA_US_percent = df_DA_US_percent.drop(columns = 'job_posted_month_no')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 df_DA_US_percent = df_DA_US_percent.set_index('job_posted_month')
# ----> 2 df_DA_US_percent = df_DA_US_percent.drop(columns = 'job_posted_month_no')
#
# File c:\Users\14312\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\14312\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\14312\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\14312\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['job_posted_month_no'] not found in axis"

# %%
df_plot = df_DA_US_percent.iloc[:, 1:6]

sns.lineplot(data = df_plot,dashes = False,legend = True)
sns.despine()

# %%
df_DA_US_percent
# Out:
# job_skills        index        sql      excel    tableau     python  \
# job_posted_month
# Jan                   0  54.167648  42.288674  29.291264  26.536379
# Feb                   1  51.730895  42.243632  27.367734  26.420640
# Mar                   2  51.881634  42.795111  29.012544  27.066581
# Apr                   3  53.231939  42.139197  29.575136  27.756654
# May                   4  51.692369  42.419387  28.680152  27.017825
# Jun                   5  50.360725  41.914482  28.646841  28.312511
# Jul                   6  50.163430  40.722938  29.475101  27.648529
# Aug                   7  51.462165  41.166717  29.409105  30.524570
# Sep                   8  49.471869  38.823022  29.165768  26.492779
# Oct                   9  48.833238  36.463669  27.110605  26.048188
# Nov                  10  45.332156  33.833591  25.336570  23.151622
# Dec                  11  46.443830  38.326213  27.142498  27.041970
#
# job_skills              sas          r   power bi       word  powerpoint  ...  \
# job_posted_month                                                          ...
# Jan               21.568166  17.812574  15.740523  11.396280   11.443372  ...
# Feb               19.790986  17.064010  18.321359  12.050947   11.512084  ...
# Mar               19.909939  18.349952  16.950788  11.836603   10.759087  ...
# Apr               21.524219  17.159861  17.473963  11.489502   10.745578  ...
# May               19.467254  17.364310  17.224114  11.155618   10.314440  ...
# Jun               17.314799  17.895478  17.402780  12.686961   10.980116  ...
# Jul               19.150163  16.939050  16.939050  11.286291   10.555662  ...
# Aug               19.234248  19.158879  18.209225  11.335544   11.245101  ...
# Sep               18.452253  16.081052  17.676223  10.303945   10.239276  ...
# Oct               18.212863  15.841396  17.472965   9.447923    8.973629  ...
# Nov               17.479585  14.279409  15.051865   9.490179    8.894284  ...
# Dec               19.602915  16.536818  17.567228  11.334506    9.901985  ...
#
# job_skills        capacitor   chainer  asp.net core        qt  \
# job_posted_month
# Jan                0.011773  0.000000      0.000000  0.000000
# Feb                0.000000  0.000000      0.000000  0.000000
# Mar                0.000000  0.000000      0.000000  0.000000
# Apr                0.000000  0.000000      0.000000  0.000000
# May                0.000000  0.000000      0.000000  0.000000
# Jun                0.000000  0.000000      0.000000  0.017596
# Jul                0.000000  0.000000      0.000000  0.000000
# Aug                0.000000  0.000000      0.000000  0.000000
# Sep                0.000000  0.000000      0.000000  0.000000
# Oct                0.000000  0.000000      0.018972  0.000000
# Nov                0.000000  0.000000      0.000000  0.000000
# Dec                0.000000  0.025132      0.000000  0.000000
#
# job_skills        microsoft lists  msaccess    kotlin  openstack    theano  \
# job_posted_month
# Jan                      0.000000  0.000000  0.000000   0.000000  0.000000
# Feb                      0.000000  0.000000  0.000000   0.000000  0.000000
# Mar                      0.000000  0.000000  0.000000   0.000000  0.000000
# Apr                      0.000000  0.000000  0.000000   0.000000  0.000000
# May                      0.000000  0.020028  0.000000   0.000000  0.000000
# Jun                      0.000000  0.000000  0.017596   0.017596  0.000000
# Jul                      0.000000  0.000000  0.000000   0.000000  0.000000
# Aug                      0.000000  0.000000  0.000000   0.000000  0.000000
# Sep                      0.000000  0.000000  0.000000   0.000000  0.000000
# Oct                      0.000000  0.000000  0.000000   0.000000  0.000000
# Nov                      0.000000  0.000000  0.000000   0.000000  0.000000
# Dec                      0.025132  0.000000  0.000000   0.000000  0.025132
#
# job_skills         xamarin
# job_posted_month
# Jan               0.000000
# Feb               0.000000
# Mar               0.016082
# Apr               0.000000
# May               0.000000
# Jun               0.000000
# Jul               0.000000
# Aug               0.000000
# Sep               0.000000
# Oct               0.000000
# Nov               0.000000
# Dec               0.000000
#
# [12 rows x 219 columns]
